# %% [markdown]
# # Importing libraries

# %% [markdown]
# #  There is a car YOLO

# %% [markdown]
# # type

# %% [markdown]
# # plaque

# %% [markdown]
# # extract text

# %% [markdown]
# ## Data

# %% [markdown]
# ## extract features

# %% [markdown]
# ## model
